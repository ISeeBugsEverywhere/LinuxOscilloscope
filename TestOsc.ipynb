# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import sqlite3
import mysql.connector as cnt
import plotly.express as px

# %%
from HWaccess.Devices.Rigol_DHO802_VISA_USB import Oscilloscope

# %%
import pyvisa as visa

# %%
RM = visa.ResourceManager('@py')

# %%
rs = RM.list_resources(); rs[-1]
# Out:
# 'USB0::6833::1101::DHO8B253700667::0::INSTR'

# %%
device = RM.open_resource(rs[-1])

# %%
osc = Oscilloscope()
osc.init_device(device, params=None)

# %%
osc.get_name()
# Out:
# 'RIGOL TECHNOLOGIES,DHO802,DHO8B253700667,00.01.00\n'

# %%
t, v = osc.get_xy('CHAN1')

# %%
plt.plot(t, v)
plt.axhline(y=0, color='red')
plt.axvline(x=0, color='red')
plt.show()

# %%
device.close()
